# %%
import pywencai

res = pywencai.get(question='昨日振幅>=9%', sort_order='asc', loop=True)
res
# Out:
#           股票代码  股票简称    最新价    最新涨跌幅 振幅[20230509] 涨跌幅:前复权[20230509]
# 0    873122.BJ   中纺标  12.55  -12.787    29.300291        4.88338192  \
# 1    836699.BJ   海达尔  12.00  -20.792    29.268292       47.80487805
# 2    836892.BJ  广咨国际  12.80  -15.734    26.040061       17.02619414
# 3    301270.SZ  汉仪股份  63.69   13.086    21.724344       12.66253251
# 4    688001.SH  华兴源创  36.87   -1.338    20.938967       16.96400626
# ..         ...   ...    ...      ...          ...               ...
# 227  688661.SH  和林微纳  76.25   -3.481      9.14888        2.81103592
# 228  600730.SH  中国高科   7.27    9.985     9.077809       -4.75504323
# 229  600640.SH  国脉文化  13.98    3.097     9.069946        4.22751729
# 230  300059.SZ  东方财富  16.08   -2.957     9.057071        2.79156328
# 231  835174.BJ  五新隧装   8.69   -3.013     9.015544       -7.15025907
#
#     涨跌[20230509] 成交量[20230509]  成交额[20230509] market_code    code
# 0           0.67       5836601   8.85025611E7         151  873122
# ...

# %%
import pywencai

res = pywencai.get(question='A股成交额', query_type='zhishu')
res
# Out:
#             主动卖出特大单金额         被动买入特大单金额              成交量               成交额
# 0     48105674000.000   37373630000.000  53885588000.000  645228490000.000  \
# 1    94912136000.0000  79518517000.0000     105217012000     1221520790000
# 2    75215542000.0000  73998901000.0000      97294848000     1136648420000
# 3    76884075000.0000  64205571000.0000      87803170000     1070937870000
# 4    81419256000.0000  73204500000.0000      96468734000     1171327740000
# 5    67778802000.0000  71001692000.0000      85442325000     1116454370000
# 6    69607773000.0000  58470302000.0000      75699548000     1044723000000
# 7    76057263000.0000  68139838000.0000      79615273000     1122033070000
# 8    77914019000.0000  63676280000.0000      84432346000     1133737300000
# 9    72989284000.0000  63067726000.0000      78107612000     1083142690000
# 10  104664053000.0000  75868838000.0000      86629574000     1217654600000
# ...

# %%
import pywencai

res = pywencai.get(question='兆易创新十大股东')
res['十大股东变化']
# Out:
#    变动类型   股本性质  持股比例                报告期  股票简称 诊股-十大股东报告期明细
# 0    -1   流通A股  6.86  20210630-20230630  兆易创新     20220331  \
# 1    -1   流通A股  5.18  20210630-20230630  兆易创新     20220331
# 2    -1   流通A股  3.74  20210630-20230630  兆易创新     20220331
# 3     0  受限流通股  3.30  20210630-20230630  兆易创新     20220331
# 4    -1   流通A股  3.28  20210630-20230630  兆易创新     20220331
# 5    -1   流通A股  3.11  20210630-20230630  兆易创新     20220331
# 6     1   流通A股  2.46  20210630-20230630  兆易创新     20220331
# 7     0   流通A股  1.72  20210630-20230630  兆易创新     20220331
# 8     1   流通A股  1.53  20210630-20230630  兆易创新     20220331
# 9     1   流通A股  1.45  20210630-20230630  兆易创新     20220331
#
#                                   大股东名称      变动股数  诊股-十大股东上期持股数量明细       股票代码
# 0                                   朱一明  -7211600         52969613  603986.SH  \
# 1                            香港中央结算有限公司 -15438996         50019297  603986.SH
# 2                      InfoGrid Limited  -6334661         31289061  603986.SH
# ...

# %%
import pywencai

res = pywencai.get(question='GDP', query_type='macro')
res
# Out:
# {}
