# %%
import pywencai

res = pywencai.get(question='同花顺概念板块指数近5日涨幅', loop=True, query_type='zhishu')
res
# Out:
#           指数代码   指数简称 指数@同花顺概念指数  指数@区间涨跌幅:不复权[20230316-20230322]  \
# 0    886039.TI  ERP概念    同花顺概念指数                              NaN
# 1    886038.TI   超导概念    同花顺概念指数                        -0.292598
# 2    886037.TI   6G概念    同花顺概念指数                         0.843078
# 3    886036.TI  时空大数据    同花顺概念指数                         3.627599
# 4    886035.TI  毫米波雷达    同花顺概念指数                         2.245757
# ..         ...    ...        ...                              ...
# 377  885338.TI   融资融券    同花顺概念指数                         0.737056
# 378  885333.TI   移动支付    同花顺概念指数                         3.292527
# 379  885312.TI    物联网    同花顺概念指数                         3.583109
# 380  885311.TI   智能电网    同花顺概念指数                         1.601623
# 381  885284.TI   稀缺资源    同花顺概念指数                         0.305088
#
#     指数@收盘价:不复权[20230322] 指数@涨跌幅:前复权[20230322] market_code    code
# 0               1018.200                1.089          48  886039
# ...

# %%
import pywencai

res = pywencai.get(question='申万行业', loop=True)
res
# Out:
#            股票代码  股票简称        所属申万行业    最新价  最新涨跌幅 market_code    code
# 0     300208.SZ  青岛中程  综合--综合Ⅱ--综合Ⅲ  10.14  1.098          33  300208
# 1     000622.SZ  恒立实业  综合--综合Ⅱ--综合Ⅲ   4.84  0.624          33  000622
# 2     600770.SH  综艺股份  综合--综合Ⅱ--综合Ⅲ   6.75  0.446          17  600770
# 3     600070.SH  浙江富润  综合--综合Ⅱ--综合Ⅲ   6.73  0.900          17  600070
# 4     000652.SZ  泰达股份  综合--综合Ⅱ--综合Ⅲ   4.26  0.709          33  000652
# ...         ...   ...           ...    ...    ...         ...     ...
# 5147  001367.SZ  海森药业          None    NaN    NaN          33  001367
# 5148  001287.SZ   中电港          None    NaN    NaN          33  001287
# 5149  001360.SZ  南矿集团          None    NaN    NaN          33  001360
# 5150  001328.SZ  登康口腔          None    NaN    NaN          33  001328
# 5151  601061.SH  中信金属          None    NaN    NaN          17  601061
#
# [5152 rows x 7 columns]
