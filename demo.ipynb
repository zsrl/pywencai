# %%
import pywencai

res = pywencai.get(question='退市股票', sort_key='退市@退市日期', sort_order='asc', loop=True)
res
# Out:
#        code   股票简称   退市@退市日期 market_code       股票代码
# 0    000508    琼民源  19990712          35  000508.SZ
# 1    600625   PT水仙  20010423          19  600625.SH
# 2    900931  PT水仙B  20010423         105  900931.SH
# 3    000588  PT粤金曼  20010615          35  000588.SZ
# 4    000015  PT中浩A  20011022          35  000015.SZ
# ..      ...    ...       ...         ...        ...
# 211  600090   退市济堂  20220707          19  600090.SH
# 212  600385   退市金泰  20220707          19  600385.SH
# 213  600555   退市海创  20220713          19  600555.SH
# 214  900955   退市海B  20220713         105  900955.SH
# 215  600896   退市海医  20220725          19  600896.SH
#
# [216 rows x 5 columns]

# %%
import pywencai

res = pywencai.get(question='二十日均线', loop=True)
res
# Out:
#            买入信号inter[20220923]    code  股票简称      最新价   最新涨跌幅 20日均线[20220923]  \
# 0              月线dmi金叉||周线wr超卖  600519  贵州茅台  1834.43   0.748        1861.220
# 1       周线cci买入信号||周线行情收盘价上穿5日  688032  禾迈股份  1145.90   0.849        1103.128
# 2               kdj金叉||月线psy超卖  688348  昱能科技   620.00  -1.176         649.511
# 3       bias买入信号||wr超卖||skdj超卖  300896   爱美客   456.01  -1.506         525.448
# 4                     boll突破下轨  688301  奕瑞科技   482.04   1.403         503.741
# ...                        ...     ...   ...      ...     ...             ...
# 4917       wr超卖||skdj超卖||kdj超卖  301328  维峰电子    67.11  -5.145
# 4918    kdj金叉||skdj超卖||lwr买入信号  301331  恩威医药    41.68   9.368
# 4919       wr超卖||skdj超卖||kdj超卖  301339   通行宝    16.78   0.963
# 4920  kdj超卖||周线kdj超卖||周线skdj超卖  301349  信德新材   143.70  -2.682
# 4921       wr超卖||psy超卖||周线wr超卖  301369  联动科技   127.72  -5.252
#
#      market_code  技术形态[20220923]       股票代码
# 0             17    价升量涨||阳线||放量  600519.SH
# ...
