# %%
import pywencai

res = pywencai.get(question='昨日振幅>=9%', sort_order='asc', loop=True)
res
# Out:
#           股票代码  股票简称     最新价   最新涨跌幅 振幅[20230404] 涨跌幅:前复权[20230404]  \
# 0    688343.SH  云天励飞   99.00  -4.908    79.895264      137.04462659
# 1    688535.SH  华海诚科   83.00  32.482    40.371428                79
# 2    300736.SZ  百邦科技   11.80  -9.924    23.172242      -18.83519207
# 3    301052.SZ  果麦文化   39.11   1.637    22.723404        9.16312057
# 4    688498.SH  源杰科技  249.00  20.000    22.522727       17.89772727
# ..         ...   ...     ...     ...          ...               ...
# 185  688128.SH  中国电研   23.70   2.287     9.036144        7.36793327
# 186  300275.SZ   梅安森   22.39  -2.398      9.02806       -6.71004473
# 187  300884.SZ   狄耐克   15.88   5.867     9.023569        1.01010101
# 188  000409.SZ  云鼎科技    9.09  -1.196     9.018036       -7.81563126
# 189  000999.SZ  华润三九   59.90   2.044     9.006266        5.10295434
#
#     涨跌[20230404] 成交量[20230404] 成交额[20230404] market_code    code
# 0          60.19   5.6395674E7  5.86583629E9          17  688343
# ...

# %%
import pywencai

res = pywencai.get(question='申万行业', loop=True, log=True)
res
# Out:
#            股票代码  股票简称    最新价   最新涨跌幅        所属申万行业      最新dde大单净额  \
# 0     300208.SZ  青岛中程   9.80   2.190  综合--综合Ⅱ--综合Ⅲ   -2839436.700
# 1     000622.SZ  恒立实业   4.95  -2.367  综合--综合Ⅱ--综合Ⅲ   -2374348.000
# 2     600770.SH  综艺股份   6.89   0.584  综合--综合Ⅱ--综合Ⅲ    7100166.000
# 3     600070.SH  浙江富润   5.46  -4.378  综合--综合Ⅱ--综合Ⅲ  -10004330.500
# 4     000652.SZ  泰达股份   4.44  -0.671  综合--综合Ⅱ--综合Ⅲ   -2757547.000
# ...         ...   ...    ...     ...           ...            ...
# 5161  603999.SH  读者传媒   6.19  -3.882  传媒--出版--大众出版    1219539.000
# 5162  002181.SZ   粤传媒   5.46  -4.378  传媒--出版--大众出版   -6991308.000
# 5163  600825.SH  新华传媒   4.38  -4.158  传媒--出版--大众出版    -769432.000
# 5164  301025.SZ  读客文化  12.30  -5.819  传媒--出版--大众出版   -9255005.200
# 5165  871694.BJ  中裕科技    NaN     NaN          None           None
#
#       总股本[20230406] 市盈率(pe)[20230406] market_code    code
# 0      749475000.00           -51.843          33  300208
# ...

# %%
from fake_useragent import UserAgent

ua = UserAgent()

ua.random
# Out:
# 'Mozilla/5.0 (X11; U; Linux i686 (x86_64); nl; rv:1.8.0.6) Gecko/20060728 SUSE/1.5.0.6-1.2 Firefox/1.5.0.6'
